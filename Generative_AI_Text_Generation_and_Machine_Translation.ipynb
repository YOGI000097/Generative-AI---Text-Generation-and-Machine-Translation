# %% [markdown]
# Question 1: What is Generative AI and what are its primary use cases across industries?
#
# Answer:
#
# Generative AI is a branch of artificial intelligence that focuses on creating new data such as text, images, audio, video, and code based on patterns learned from existing datasets. Unlike traditional AI models that classify or predict outcomes, generative models learn the underlying distribution of data and generate similar outputs.
#
# These models are commonly built using deep learning techniques such as Transformers, Generative Adversarial Networks (GANs), and Variational Autoencoders (VAEs).
#
# Primary Use Cases Across Industries
#
# Healthcare
#
# Drug discovery
#
# Medical report generation
#
# Synthetic medical data generation
#
# Finance
#
# Fraud detection
#
# Financial report generation
#
# Algorithmic trading insights
#
# Media & Entertainment
#
# Script writing
#
# Music composition
#
# Image and video generation
#
# Education
#
# Automated tutoring systems
#
# Content generation
#
# Language translation
#
# Software Development
#
# Code generation
#
# Debugging assistance
#
# Documentation writing
#
# Marketing
#
# Ad copy generation
#
# Personalized content creation
#
# Chatbots and virtual assistants

# %% [markdown]
# Question 2: Explain the role of probabilistic modeling in generative models. How do these models differ from discriminative models?
#
# Answer:
#
# Probabilistic modeling is fundamental to generative models because it allows the model to learn the probability distribution of data and generate new samples from that distribution.
#
# Generative models estimate:
#
# 𝑃
# (
# 𝑋
# ,
# 𝑌
# )
# P(X,Y)
#
# which represents the joint probability distribution of input features and labels.
#
# Examples include:
#
# Variational Autoencoders (VAEs)
#
# GANs
#
# Hidden Markov Models
#
# GPT models
#
# Using this distribution, generative models can generate new data samples similar to the training data.
#
# Discriminative Models
#
# Discriminative models focus only on learning the conditional probability
#
# 𝑃
# (
# 𝑌
# ∣
# 𝑋
# )
# P(Y∣X)
#
# They directly map input features to labels.
#
# Examples:
#
# Logistic Regression
#
# Support Vector Machines
#
# Neural Networks for classification

# %% [markdown]
# Question 3: Difference between Autoencoders and Variational Autoencoders (VAEs)
#
# Answer:
#
# Autoencoders and Variational Autoencoders are neural networks used for representation learning and data generation.
#
# Autoencoders
#
# Autoencoders consist of two components:
#
# Encoder – compresses input data into a latent representation.
#
# Decoder – reconstructs the original input.
#
# Architecture:
#
# Input → Encoder → Latent Vector → Decoder → Reconstructed Output
#
# Loss Function:
#
# Reconstruction loss such as Mean Squared Error (MSE).
#
# Limitation:
# They cannot easily generate new meaningful data samples.
#
# Variational Autoencoders (VAEs)
#
# VAEs extend autoencoders by learning a probability distribution over latent variables.
#
# Instead of learning a single latent vector, VAEs learn:
#
# 𝜇
# (
# 𝑚
# 𝑒
# 𝑎
# 𝑛
# )
# ,
# 𝜎
# (
# 𝑣
# 𝑎
# 𝑟
# 𝑖
# 𝑎
# 𝑛
# 𝑐
# 𝑒
# )
# μ(mean),σ(variance)
#
# The latent vector is sampled using:
#
# 𝑧
# =
# 𝜇
# +
# 𝜎
# ∗
# 𝜖
# z=μ+σ∗ϵ
#
# where
#
# 𝜖
# ∼
# 𝑁
# (
# 0
# ,
# 1
# )
# ϵ∼N(0,1)
#
# VAEs optimize two losses:
#
# Reconstruction loss
#
# KL Divergence loss
#
# This allows VAEs to generate new data samples.

# %% [markdown]
# Question 4: Attention Mechanism in Neural Machine Translation
#
# Answer:
#
# The attention mechanism allows a translation model to focus on relevant words in the source sentence when generating each word in the target sentence.
#
# Traditional encoder-decoder models compress the entire sentence into a single vector, which often loses information.
#
# Attention solves this limitation.
#
# Working Process
#
# Encoder converts input sentence into hidden states.
#
# Decoder generates output words.
#
# At each step, attention computes alignment scores between decoder state and encoder outputs.
#
# A context vector is created using weighted encoder outputs.
#
# Attention Weight:
#
# 𝛼
# 𝑖
# 𝑗
# =
# 𝑠
# 𝑜
# 𝑓
# 𝑡
# 𝑚
# 𝑎
# 𝑥
# (
# 𝑠
# 𝑐
# 𝑜
# 𝑟
# 𝑒
# (
# ℎ
# 𝑖
# ,
# 𝑠
# 𝑗
# )
# )
# α
# ij
# 	​
#
# =softmax(score(h
# i
# 	​
#
# ,s
# j
# 	​
#
# ))
#
# where:
#
# ℎ
# 𝑖
# h
# i
# 	​
#
#  = encoder hidden state
#
# 𝑠
# 𝑗
# s
# j
# 	​
#
#  = decoder state
#
# Why Attention is Critical
#
# Improves translation accuracy
#
# Handles long sentences
#
# Allows better context understanding
#
# Forms the basis for Transformer models like GPT and BERT

# %% [markdown]
# Question 5: Ethical Considerations in Generative AI
#
# Answer:
#
# When using generative AI for creative content such as poetry or storytelling, several ethical issues must be addressed.
#
# 1. Bias and Fairness
#
# Training data may contain cultural or gender biases which the model can reproduce.
#
# 2. Copyright Issues
#
# Generated text may unintentionally reproduce copyrighted material.
#
# 3. Misinformation
#
# AI can generate false or misleading narratives.
#
# 4. Plagiarism
#
# Content generated may resemble existing works.
#
# 5. Accountability
#
# Responsibility for AI-generated content must be clearly defined.
#
# Mitigation Strategies
#
# Bias detection and filtering
#
# Responsible dataset selection
#
# Human review systems
#
# Transparency about AI-generated content

# %%
# Question 6: Variational Autoencoder for Text Reconstruction
# Python Code
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import backend as K

# Dataset
sentences = [
"The sky is blue",
"The sun is bright",
"The grass is green",
"The night is dark",
"The stars are shining"
]

# Tokenization
tokenizer = Tokenizer()
tokenizer.fit_on_texts(sentences)

sequences = tokenizer.texts_to_sequences(sentences)

max_len = max(len(seq) for seq in sequences)
X = pad_sequences(sequences, maxlen=max_len)

vocab_size = len(tokenizer.word_index) + 1

# Encoder
inputs = Input(shape=(max_len,))
h = Dense(16, activation='relu')(inputs)

z_mean = Dense(8)(h)
z_log_var = Dense(8)(h)

def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], 8))
    return z_mean + K.exp(z_log_var/2) * epsilon

z = Lambda(sampling)([z_mean, z_log_var])

# Decoder
decoder = Dense(max_len, activation='sigmoid')(z)

vae = Model(inputs, decoder)

vae.compile(optimizer='adam', loss='mse')

vae.fit(X, X, epochs=50, verbose=1)

# Reconstruction
reconstructed = vae.predict(X)
print(reconstructed)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - loss: 41.3333
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 40.6193
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 41.3507
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 41.3585
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 41.3359
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 41.3074
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 40.5189
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 41.3217
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 41.2951
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 41.3406
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 41.1918
# Epoch 12/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 41.2875
# Epoch 13/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 41.2406
# Epoch 14/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 41.0385
# Epoch 15/50
# ...

# %%
# Question 7: Translation using GPT Model
# Python Code
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline

model_name = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)

translator = pipeline("translation", model=model, tokenizer=tokenizer)

text = "Artificial intelligence is transforming the world."

french = translator(text)

print("Original:", text)
print("French:", french)
# Out:
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# /usr/local/lib/python3.12/dist-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/301M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# ...

# %%
# Question 8: Attention-based Encoder Decoder Model
# Python Code (PyTorch)
import torch
import torch.nn as nn

class Encoder(nn.Module):
    def __init__(self, input_dim, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(input_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim, hidden_dim)

    def forward(self, src):
        embedded = self.embedding(src)
        outputs, hidden = self.rnn(embedded)
        return outputs, hidden

class Attention(nn.Module):
    def __init__(self, hidden_dim):
        super().__init__()
        self.attn = nn.Linear(hidden_dim*2, hidden_dim)

    def forward(self, hidden, encoder_outputs):
        weights = torch.bmm(encoder_outputs, hidden.unsqueeze(2)).squeeze(2)
        return torch.softmax(weights, dim=1)

class Decoder(nn.Module):
    def __init__(self, output_dim, emb_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(output_dim, emb_dim)
        self.rnn = nn.GRU(emb_dim + hidden_dim, hidden_dim)
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, input, hidden, context):
        embedded = self.embedding(input).unsqueeze(0)
        rnn_input = torch.cat((embedded, context.unsqueeze(0)), dim=2)
        output, hidden = self.rnn(rnn_input, hidden)
        prediction = self.fc(output.squeeze(0))
        return prediction, hidden

# %%
# Question 9: Poem Generation using GPT
# Python Code
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = """
Roses are red, violets are blue,
Sugar is sweet, and so are you.
The moon glows bright in silent skies,
"""

result = generator(prompt, max_length=40, num_return_sequences=1)

print(result[0]['generated_text'])

# %% [markdown]
# Question 10: Designing a Creative Writing Assistant
#
# Answer:
#
# To design a creative writing assistant for generating story plots and character descriptions, the following system architecture can be used.
#
# 1 Model Selection
#
# Use Transformer-based models such as:
#
# GPT-4
#
# GPT-3
#
# LLaMA
#
# T5
#
# These models excel at language generation tasks.
#
# 2 Training Data
#
# Data sources may include:
#
# Books and novels
#
# Movie scripts
#
# Short stories
#
# Online storytelling datasets
#
# 3 System Architecture
#
# Steps:
#
# User provides prompt
#
# Model generates story outline
#
# Character generator module creates character descriptions
#
# Editing module refines output

# %%
# Python Example
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "Generate a fantasy story plot about a lost kingdom."

story = generator(prompt, max_length=120)

print(story[0]['generated_text'])
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ...
